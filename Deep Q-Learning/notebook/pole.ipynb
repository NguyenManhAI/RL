# %%
import matplotlib.pyplot as plt

# Data for the learning curve (simulated scores)
scores = [10, 15, 22, 35, 42, 53, 65, 75, 83, 92, 100, 110, 120, 125, 130, 140, 150, 160, 170, 180, 
          190, 200, 210, 220, 230, 240, 250, 270, 280, 300, 310, 320, 330, 350, 360, 380, 400, 420, 
          440, 460, 480, 500]

# Plotting the learning curve
plt.plot(scores)
plt.xlabel("Episodes")
plt.ylabel("Score")
plt.title("DQN CartPole Learning Curve")
plt.show()
